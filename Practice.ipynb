# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option("display.max_rows" ,None)        # max_rows
pd.set_option("display.max_columns" ,None)    # max_columns

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Problem Statement
# You have the data for the 100 top-rated movies from the past decade along with various pieces of information about the movie, its actors, and the voters who have rated these movies online. In this assignment, you will try to find some interesting insights into these movies and their voters, using Python.

# %% [markdown]
# # Subtask 1.1: Read the Movies Data.

# %%
# We have to load data by using pd

# %%
df = pd.read_csv("J:\\Learn Data Science\\Case Study\\Imdb+Movie\\Movie+Assignment+Data.csv")

# %%
df
# Out:
#                                               Title  title_year     budget  \
# 0                                        La La Land        2016   30000000
# 1                                          Zootopia        2016  150000000
# 2                                              Lion        2016   12000000
# 3                                           Arrival        2016   47000000
# 4                             Manchester by the Sea        2016    9000000
# 5                                Hell or High Water        2016   12000000
# 6                                    Doctor Strange        2016  165000000
# 7                                           Tangled        2010  260000000
# 8                             The Dark Knight Rises        2012  250000000
# 9                        Captain America: Civil War        2016  250000000
# 10              The Hobbit: The Desolation of Smaug        2013  225000000
# ...

# %%
df.head()
# Out:
#                    Title  title_year     budget      Gross      actor_1_name  \
# 0             La La Land        2016   30000000  151101803      Ryan Gosling
# 1               Zootopia        2016  150000000  341268248  Ginnifer Goodwin
# 2                   Lion        2016   12000000   51738905         Dev Patel
# 3                Arrival        2016   47000000  100546139         Amy Adams
# 4  Manchester by the Sea        2016    9000000   47695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating    genre_1  \
# ...

# %% [markdown]
# # Subtask 1.2: Inspect the Dataframe

# %%
# It's Means Check shape(dimension) ,Null Value (info), Describe data

# %%
df.shape                # DImension
# Out:
# (100, 62)

# %%
df.info()           # Null Value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
# Let's check the summary of different numeric columns.
df.describe()
# Out:
#         title_year        budget         Gross  actor_1_facebook_likes  \
# count   100.000000  1.000000e+02  1.000000e+02              100.000000
# mean   2012.820000  7.838400e+07  1.468679e+08            13407.270000
# std       1.919491  7.445295e+07  1.454004e+08            10649.037862
# min    2010.000000  3.000000e+06  2.238380e+05               39.000000
# 25%    2011.000000  1.575000e+07  4.199752e+07             1000.000000
# 50%    2013.000000  4.225000e+07  1.070266e+08            13000.000000
# 75%    2014.000000  1.500000e+08  2.107548e+08            20000.000000
# max    2016.000000  2.600000e+08  9.366622e+08            35000.000000
#
#        actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  \
# count               99.000000               98.000000   100.000000
# mean              7377.303030             3002.153061     7.883000
# std              13471.568216             6940.301133     0.247433
# ...

# %% [markdown]
# #  Task 2: Data Analysis
# Now that we have loaded the dataset and inspected it, we see that most of the data is in place. As of now, no data cleaning is required, so let's start with some data manipulation, analysis, and visualisation to get various insights about the data.

# %% [markdown]
# # Subtask 2.1: Reduce those Digits!
#
# These numbers in the budget and gross are too big, compromising its readability. Let's convert the unit of the budget and gross columns from $ to million $ first.

# %%
# It's mean budget & Gross column chya number ahet tyana divided karu ya ki thode numric(magche) no. kami hotil

# %%
# So! Let's Devide it by 10000

df['budget'] = df['budget']/10000
df['Gross'] = df['Gross']/10000

# %%
df
# Out:
#                                               Title  title_year   budget  \
# 0                                        La La Land        2016   3000.0
# 1                                          Zootopia        2016  15000.0
# 2                                              Lion        2016   1200.0
# 3                                           Arrival        2016   4700.0
# 4                             Manchester by the Sea        2016    900.0
# 5                                Hell or High Water        2016   1200.0
# 6                                    Doctor Strange        2016  16500.0
# 7                                           Tangled        2010  26000.0
# 8                             The Dark Knight Rises        2012  25000.0
# 9                        Captain America: Civil War        2016  25000.0
# 10              The Hobbit: The Desolation of Smaug        2013  22500.0
# 11                                     The Avengers        2012  22000.0
# ...

# %% [markdown]
# # Subtask 2.2: Let's Talk Profit!
#
# 1)Create a new column called profit which contains the difference of the two columns: gross and budget.
# Sort the dataframe using the profit column as reference.
#
# 2)Extract the top ten profiting movies in descending order and store them in a new dataframe - top10.
#
# 3)Plot a scatter or a joint plot between the columns budget and profit and write a few words on what you observed.
#
# 4)Extract the movies with a negative profit and store them in a new dataframe - neg_profit

# %%
# 1 ) hya mdhe new colomns create karayla sangat ahe [Profit] navacha & then tya columns madhe 
# gross & budget colomn la minus karyach ahe & value put karaychi ahe profit colomn madhe

# %%
df['profit'] = df['Gross'] - df['budget']
df
# Out:
#                                               Title  title_year   budget  \
# 0                                        La La Land        2016   3000.0
# 1                                          Zootopia        2016  15000.0
# 2                                              Lion        2016   1200.0
# 3                                           Arrival        2016   4700.0
# 4                             Manchester by the Sea        2016    900.0
# 5                                Hell or High Water        2016   1200.0
# 6                                    Doctor Strange        2016  16500.0
# 7                                           Tangled        2010  26000.0
# 8                             The Dark Knight Rises        2012  25000.0
# 9                        Captain America: Civil War        2016  25000.0
# 10              The Hobbit: The Desolation of Smaug        2013  22500.0
# 11                                     The Avengers        2012  22000.0
# ...

# %%
# 2) profit chya colomns ne  data la sorting karay ch ki data displya hoil highest no.chya profit ne

# %%
df = df.sort_values(by= 'profit',ascending= False)
df
# Out:
#                                               Title  title_year   budget  \
# 97       Star Wars: Episode VII - The Force Awakens        2015  24500.0
# 11                                     The Avengers        2012  22000.0
# 47                                         Deadpool        2016   5800.0
# 32                  The Hunger Games: Catching Fire        2013  13000.0
# 12                                      Toy Story 3        2010  20000.0
# 8                             The Dark Knight Rises        2012  25000.0
# 45                                   The Lego Movie        2014   6000.0
# 1                                          Zootopia        2016  15000.0
# 41                                    Despicable Me        2010   6900.0
# 18                                       Inside Out        2015  17500.0
# 34                                          Gravity        2013  10000.0
# 19                          Guardians of the Galaxy        2014  17000.0
# ...

# %%
# Printing Top 10 Movies according to profit colomns

# %%
df.iloc[:10 , :]
# Out:
#                                          Title  title_year   budget  \
# 97  Star Wars: Episode VII - The Force Awakens        2015  24500.0
# 11                                The Avengers        2012  22000.0
# 47                                    Deadpool        2016   5800.0
# 32             The Hunger Games: Catching Fire        2013  13000.0
# 12                                 Toy Story 3        2010  20000.0
# 8                        The Dark Knight Rises        2012  25000.0
# 45                              The Lego Movie        2014   6000.0
# 1                                     Zootopia        2016  15000.0
# 41                               Despicable Me        2010   6900.0
# 18                                  Inside Out        2015  17500.0
#
#          Gross       actor_1_name       actor_2_name           actor_3_name  \
# 97  93666.2225        Doug Walker         Rob Walker                      0
# ...

# %%
# 3)Plot a scatter or a joint plot between the columns budget and profit and write a few words on what you observed.

# %%
x = df['budget']
y = df['profit']

# %%
plt.figure(figsize = [10,5])
plt.title("Movies Review")
plt.scatter(x, y , color = 'g')
plt.xlabel('Budget Of Movies')
plt.ylabel('Profit of Movies')
# plt.legend
plt.show()

# %% [markdown]
# #  I have observed in above graph is that , On X-axis the movies budget from 1000 - 5000 is avg profit is 7000 , One Highest profit movie is budget is 23000 , & Avg movie profit of any type of movie is 30000

# %%
# Extract the movies with a negative profit and store them in a new dataframe - neg_profit

# Means Profit chya colomns madhun Negative profit kadhayc ch ahe

# %%
df[df["profit"]< 0 ] .head()
# Out:
#                       Title  title_year  budget      Gross      actor_1_name  \
# 99  Tucker and Dale vs Evil        2010   500.0    22.3838    Katrina Bowden
# 89                    Amour        2012   890.0    22.5377  Isabelle Huppert
# 56                     Rush        2013  3800.0  2690.3709   Chris Hemsworth
# 66                  Warrior        2011  2500.0  1365.1662         Tom Hardy
# 82                  Flipped        2010  1400.0   175.2214  Madeline Carroll
#
#          actor_2_name            actor_3_name  actor_1_facebook_likes  \
# 99       Tyler Labine          Chelan Simmons                     948
# 89    Emmanuelle Riva  Jean-Louis Trintignant                     678
# 56       Olivia Wilde    Alexandra Maria Lara                   26000
# 66       Frank Grillo              Kevin Dunn                   27000
# 82  Rebecca De Mornay             Aidan Quinn                    1000
#
#     actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating genre_1  \
# ...

# %% [markdown]
# # Subtask 2.3: The General Audience and the Critics

# %%
# So in that task we have to perform on Rating clomns

# %%
# 1) Firstly we have to divided MetaCritic columns by '10'

# %%
df['MetaCritic'].head()
# Out:
# 97    81.0
# 11    69.0
# 47    65.0
# 32    76.0
# 12    92.0
# Name: MetaCritic, dtype: float64

# %%
df["MetaCritic"] = df['MetaCritic'] /10     # Making  Metacritic columns in 100 scale
df
# Out:
#                                               Title  title_year   budget  \
# 97       Star Wars: Episode VII - The Force Awakens        2015  24500.0
# 11                                     The Avengers        2012  22000.0
# 47                                         Deadpool        2016   5800.0
# 32                  The Hunger Games: Catching Fire        2013  13000.0
# 12                                      Toy Story 3        2010  20000.0
# 8                             The Dark Knight Rises        2012  25000.0
# 45                                   The Lego Movie        2014   6000.0
# 1                                          Zootopia        2016  15000.0
# 41                                    Despicable Me        2010   6900.0
# 18                                       Inside Out        2015  17500.0
# 34                                          Gravity        2013  10000.0
# 19                          Guardians of the Galaxy        2014  17000.0
# ...

# %%
# 2) Let's Find the avg of Metacriticas and IMDb ratings

# %%
df["avg_rt"] = (df["IMDb_rating"]+df["MetaCritic"] )/2

# %%
df
# Out:
#                                               Title  title_year   budget  \
# 97       Star Wars: Episode VII - The Force Awakens        2015  24500.0
# 11                                     The Avengers        2012  22000.0
# 47                                         Deadpool        2016   5800.0
# 32                  The Hunger Games: Catching Fire        2013  13000.0
# 12                                      Toy Story 3        2010  20000.0
# 8                             The Dark Knight Rises        2012  25000.0
# 45                                   The Lego Movie        2014   6000.0
# 1                                          Zootopia        2016  15000.0
# 41                                    Despicable Me        2010   6900.0
# 18                                       Inside Out        2015  17500.0
# 34                                          Gravity        2013  10000.0
# 19                          Guardians of the Galaxy        2014  17000.0
# ...

# %%
# 2) Task 2 is find absolute difference from metarating & Imdb Rate

# %%
df2 = df[["Title","IMDb_rating","MetaCritic","avg_rt"]]
df2 =  df2.loc[abs(df2["IMDb_rating"]-df2['MetaCritic']  < 0.5 )]
df2
# Out:
#                                               Title  IMDb_rating  MetaCritic  \
# 97       Star Wars: Episode VII - The Force Awakens          8.1         8.1
# 32                  The Hunger Games: Catching Fire          7.6         7.6
# 12                                      Toy Story 3          8.3         9.2
# 45                                   The Lego Movie          7.8         8.3
# 1                                          Zootopia          8.1         7.8
# 18                                       Inside Out          8.2         9.4
# 34                                          Gravity          7.8         9.6
# 9                        Captain America: Civil War          7.9         7.5
# 55                                        True Grit          7.6         8.0
# 76                                The King's Speech          8.0         8.8
# 0                                        La La Land          8.2         9.3
# ...

# %%
df2 = df2.sort_values(by = 'avg_rt' ,ascending= False )
UniversalAcclaim = df2.loc[df2["avg_rt"] >=8]
UniversalAcclaim.head()
# Out:
#                Title  IMDb_rating  MetaCritic  avg_rt
# 94           Boyhood          7.9        10.0    8.95
# 69  12 Years a Slave          8.1         9.6    8.85
# 18        Inside Out          8.2         9.4    8.80
# 12       Toy Story 3          8.3         9.2    8.75
# 0         La La Land          8.2         9.3    8.75

# %% [markdown]
# # Subtask 2.4: Find the Most Popular Trios - I
#
# You're a producer looking to make a blockbuster movie. There will primarily be three lead roles in your movie and you wish to cast the most popular actors for it.
#
#
# The dataframe has three columns to help you out for the same, viz. actor_1_facebook_likes, actor_2_facebook_likes, and actor_3_facebook_likes. Your objective is to find the trios which has the most number of Facebook likes combined. That is, the sum of actor_1_facebook_likes, actor_2_facebook_likes and actor_3_facebook_likes should be maximum. Find out the top 5 popular trios, and output their names in a list.

# %%
# Task is that We have to calculate All three facebook likes of actors & then find out karyach ki which trio was work 
# together & have Max likes on FB

# %%
grp =  df.pivot_table(values=  ["actor_1_facebook_likes","actor_2_facebook_likes","actor_3_facebook_likes"],
                      aggfunc = "sum" ,index = ["actor_1_name","actor_2_name","actor_3_name"])

# %%
grp
# Out:
#                                                                      actor_1_facebook_likes  \
# actor_1_name             actor_2_name        actor_3_name
# Aidan Turner             Adam Brown          James Nesbitt                            10000
# Albert Finney            Helen McCrory       Rory Kinnear                               883
# Aldis Hodge              Neil Brown Jr.      R. Marcos Taylor                           559
# Amy Adams                Jeremy Renner       Forest Whitaker                          35000
# Amy Poehler              Mindy Kaling        Phyllis Smith                             1000
# Andrew Garfield          Dustin Fitzsimons   Marcella Lentz-Pope                      10000
# Anna Kendrick            Kieran Culkin       Ellen Wong                               10000
# Benedict Cumberbatch     Bruce Greenwood     Noel Clarke                              19000
# ...

# %%
grp.shape
# Out:
# (99, 3)

# %%
# Making Total of All FB Likes
grp["Total Likes"] = grp["actor_1_facebook_likes"] + grp["actor_2_facebook_likes"] +grp["actor_3_facebook_likes"]

# %%
grp.head()
# Out:
#                                                actor_1_facebook_likes  \
# actor_1_name  actor_2_name   actor_3_name
# Aidan Turner  Adam Brown     James Nesbitt                      10000
# Albert Finney Helen McCrory  Rory Kinnear                         883
# Aldis Hodge   Neil Brown Jr. R. Marcos Taylor                     559
# Amy Adams     Jeremy Renner  Forest Whitaker                    35000
# Amy Poehler   Mindy Kaling   Phyllis Smith                       1000
#
#                                                actor_2_facebook_likes  \
# actor_1_name  actor_2_name   actor_3_name
# Aidan Turner  Adam Brown     James Nesbitt                     1944.0
# Albert Finney Helen McCrory  Rory Kinnear                       563.0
# Aldis Hodge   Neil Brown Jr. R. Marcos Taylor                   427.0
# Amy Adams     Jeremy Renner  Forest Whitaker                   5300.0
# Amy Poehler   Mindy Kaling   Phyllis Smith                      767.0
#
# ...

# %%
# Let's Find out Most Likes 

grp.sort_values(by = ['Total Likes'] , ascending= False ,inplace= True)

# %%
grp
# Out:
#                                                                      actor_1_facebook_likes  \
# actor_1_name             actor_2_name        actor_3_name
# Dev Patel                Nicole Kidman       Rooney Mara                              33000
# Leonardo DiCaprio        Tom Hardy           Joseph Gordon-Levitt                     29000
# Jennifer Lawrence        Peter Dinklage      Hugh Jackman                             34000
# Casey Affleck            Michelle Williams   Kyle Chandler                              518
# Tom Hardy                Christian Bale      Joseph Gordon-Levitt                     27000
# Jennifer Lawrence        Robert De Niro      Bradley Cooper                           34000
# Chris Hemsworth          Robert Downey Jr.   Scarlett Johansson                       26000
# Benedict Cumberbatch     Chiwetel Ejiofor    Rachel McAdams                           19000
# ...

# %%
grp.reset_index(inplace=True)

# %%
grp
# Out:
#                 actor_1_name         actor_2_name            actor_3_name  \
# 0                  Dev Patel        Nicole Kidman             Rooney Mara
# 1          Leonardo DiCaprio            Tom Hardy    Joseph Gordon-Levitt
# 2          Jennifer Lawrence       Peter Dinklage            Hugh Jackman
# 3              Casey Affleck   Michelle Williams            Kyle Chandler
# 4                  Tom Hardy       Christian Bale    Joseph Gordon-Levitt
# 5          Jennifer Lawrence       Robert De Niro          Bradley Cooper
# 6            Chris Hemsworth    Robert Downey Jr.      Scarlett Johansson
# 7       Benedict Cumberbatch     Chiwetel Ejiofor          Rachel McAdams
# 8           Ginnifer Goodwin        Jason Bateman              Idris Elba
# 9               Ryan Gosling       Christian Bale         Charlie Talbert
# 10         Leonardo DiCaprio            Tom Hardy              Lukas Haas
# 11    Philip Seymour Hoffman         Robin Wright               Brad Pitt
# ...

# %%
# Here we Go we printing top Five likes of Actors
grp = grp.iloc[0:5,:]
grp
# Out:
#         actor_1_name        actor_2_name          actor_3_name  \
# 0          Dev Patel       Nicole Kidman           Rooney Mara
# 1  Leonardo DiCaprio           Tom Hardy  Joseph Gordon-Levitt
# 2  Jennifer Lawrence      Peter Dinklage          Hugh Jackman
# 3      Casey Affleck  Michelle Williams          Kyle Chandler
# 4          Tom Hardy      Christian Bale  Joseph Gordon-Levitt
#
#    actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 0                   33000                 96000.0                  9800.0
# 1                   29000                 27000.0                 23000.0
# 2                   34000                 22000.0                 20000.0
# 3                     518                 71000.0                  3300.0
# 4                   27000                 23000.0                 23000.0
#
#    Total Likes
# 0     138800.0
# 1      79000.0
# 2      76000.0
# 3      74818.0
# 4      73000.0

# %% [markdown]
# # Subtask 2.5: Find the Most Popular Trios - II
#
# In that We are finding trio that Actor_1 Fb Likes most and Actor_3 should be Half of the Actor_1

# %%
# Your answer here (optional)
j=0
for i in grp["Total Likes"]:
    temp=sorted([grp.loc[j,"actor_1_facebook_likes"],grp.loc[j,"actor_2_facebook_likes"],grp.loc[j,"actor_3_facebook_likes"]])
    if temp[0]>= temp[1]/2 and temp[0]>=temp[2]/2 and temp[1]>=temp[2]/2:
        print(sorted([grp.loc[j,"actor_1_name"],grp.loc[j,"actor_2_name"],grp.loc[j,"actor_3_name"]]))

    j=j+1
# Out:
# ['Joseph Gordon-Levitt', 'Leonardo DiCaprio', 'Tom Hardy']
# ['Hugh Jackman', 'Jennifer Lawrence', 'Peter Dinklage']
# ['Christian Bale', 'Joseph Gordon-Levitt', 'Tom Hardy']

# %% [markdown]
# #  Subtask 2.6: Runtime Analysis
#
# Taski is that Plot Histogram of Run time Analysis Columns

# %%
sns.set()
sns.distplot(df["Runtime"]  , label = "Duration" , color="r")
plt.legend()
plt.show()

# %% [markdown]
# # Subtask 2.7: R-Rated Movies
#
# The  Task is Find R rated movie that voted by Under_18 age grp

# %%
df.loc[df["content_rating"] == "R"] .sort_values(by = "CVotesU18" , ascending = False ) [["Title" , "CVotesU18"]] .head(10)
# Out:
#                                               Title  CVotesU18
# 47                                         Deadpool       4598
# 36                          The Wolf of Wall Street       3622
# 35                                 Django Unchained       3250
# 29                               Mad Max: Fury Road       3159
# 95                                         Whiplash       2878
# 31                                     The Revenant       2619
# 40                                   Shutter Island       2321
# 43                                        Gone Girl       2286
# 65                         The Grand Budapest Hotel       2083
# 72  Birdman or (The Unexpected Virtue of Ignorance)       1891

# %% [markdown]
# #  Task 3 : Demographic analysis

# %% [markdown]
# # Subtask 3.1 Combine the Dataframe by Genres

# %%
# So! Task is that we have to combine All genre of movies

# %%
# Creating New Data Frame by Name df_by_genre

df_by_genre = df.loc[:,"CVotes10":"VotesnUS"]
df_by_genre[["genre_1","genre_2","genre_3"]] = df[["genre_1","genre_2","genre_3"]]

# %%
df_by_genre
# Out:
#     CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  CVotes04  \
# 97    155391    161810    166378     99402     40734     18060      8751
# 11    260257    234203    264290    162604     67579     27957     12176
# 47    147467    147966    170810    105717     41811     15510      7046
# 32     85219     83874    150153    121748     50575     18571      7591
# 12    139773    149992    158704     88289     31291     11850      4859
# 8     380589    341965    281426    134959     50406     20106      9589
# 45     41269     50795     83773     55181     21793      8596      3680
# 1      53626     70912    102352     57261     16719      4539      1467
# 41     56474     66298    136943    102534     35207     11448      4000
# 18     87509    113244    119801     67153     24210      8542      3349
# 34     89986    127616    169693    122275     57564     25393     12286
# 19    156606    185326    216876    127878     49009     18501      8326
# ...

# %%
# Now creating column as 'cnt|'

# %%
df_by_genre["cnt"] = 1

# %%
df_by_genre
# Out:
#     CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  CVotes04  \
# 97    155391    161810    166378     99402     40734     18060      8751
# 11    260257    234203    264290    162604     67579     27957     12176
# 47    147467    147966    170810    105717     41811     15510      7046
# 32     85219     83874    150153    121748     50575     18571      7591
# 12    139773    149992    158704     88289     31291     11850      4859
# 8     380589    341965    281426    134959     50406     20106      9589
# 45     41269     50795     83773     55181     21793      8596      3680
# 1      53626     70912    102352     57261     16719      4539      1467
# 41     56474     66298    136943    102534     35207     11448      4000
# 18     87509    113244    119801     67153     24210      8542      3349
# 34     89986    127616    169693    122275     57564     25393     12286
# 19    156606    185326    216876    127878     49009     18501      8326
# ...

# %%
# Group the movies by individual genres
df_by_g1 =df_by_genre.groupby("genre_1").aggregate(np.sum)
df_by_g2 =df_by_genre.groupby("genre_2").aggregate(np.sum)
df_by_g3 =df_by_genre.groupby("genre_3").aggregate(np.sum)

# %%
df_by_g1
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_1
# Action      2928407   3261919   4247693   2662020    986774    364234
# Adventure   1058779   1179818   1560541    966275    365486    136985
# Animation    681562    798227   1153214    722782    251076     83069
# Biography    666831   1088430   1654704    962977    306247    100005
# Comedy       371217    496905    770395    518566    205434     81933
# Crime        383290    690221   1083469    627593    206756     71460
# Drama       1080725   1494053   1827363   1078966    417205    163874
# Mystery      150405    230844    278844    132349     45167     15615
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# genre_1
# Action       156150     89483     61975    162426     9994618       1858890
# Adventure     58559     33174     22018     48100     3535070        802902
# Animation     30718     15733     10026     25193     2282985        724844
# ...

# %%
# Now let's add all g1 series in df_add
df_add = df_by_g1.add(df_by_g2,fill_value = 0)
df_add = df_add.add(df_by_g3,fill_value = 0)
df_add
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
# Crime       574526.0   967118.0  1419495.0   821390.0   278391.0   98690.0
# Drama      3404438.0  4935375.0  7107053.0  4319700.0  1529356.0  552312.0
# Family       98165.0    95675.0   180381.0   143401.0    59137.0   22971.0
# Fantasy     572452.0   602223.0   889767.0   599747.0   241831.0   93484.0
# History     151261.0   260387.0   394531.0   223062.0    67861.0   21233.0
# Horror       16572.0    19818.0    44460.0    35863.0    13456.0    4588.0
# ...

# %%
# Let's Extract the top 10 occurence

genre_top_10 = df_add.loc[df_add["cnt"]>10]

# %%
genre_top_10
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
# Crime       574526.0   967118.0  1419495.0   821390.0   278391.0   98690.0
# Drama      3404438.0  4935375.0  7107053.0  4319700.0  1529356.0  552312.0
# Romance     549959.0   689492.0  1069280.0   712841.0   281289.0  110901.0
# Sci-Fi     2325284.0  2530855.0  3002994.0  1802098.0   671811.0  254175.0
# Thriller   1081701.0  1465491.0  1993378.0  1175799.0   416046.0  149953.0
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# ...

# %%
# Take the mean for every column by dividing with cnt 
genre_top_10.iloc[:,0:-1]=genre_top_10.iloc[:,0:-1].divide(genre_top_10["cnt"],axis=0)

# %%
genre_top_10
# Out:
#                 CVotes10       CVotes09       CVotes08       CVotes07  \
# Action     102144.096774  114433.193548  150895.322581   94262.129032
# Adventure   94596.289474  105636.631579  138482.315789   86367.921053
# Animation   61960.181818   72566.090909  104837.636364   65707.454545
# Biography   47333.500000   77867.111111  123948.777778   74054.444444
# Comedy      60157.217391   77173.347826  108993.521739   69176.913043
# Crime       52229.636364   87919.818182  129045.000000   74671.818182
# Drama       52375.969231   75928.846154  109339.276923   66456.923077
# Romance     42304.538462   53037.846154   82252.307692   54833.923077
# Sci-Fi     136781.411765  148873.823529  176646.705882  106005.764706
# Thriller    83207.769231  112730.076923  153336.769231   90446.076923
#
#                CVotes06      CVotes05     CVotes04     CVotes03     CVotes02  \
# Action     34688.838710  12693.032258  5386.129032  3064.645161  2115.258065
# ...

# %%
genre_top_10.loc[:,"VotesM":"VotesnUS"]=round(genre_top_10.loc[:,"VotesM":"VotesnUS"],2)

# %%
genre_top_10[genre_top_10.loc[:,"CVotes10":"CVotesnUS"].columns]=genre_top_10[genre_top_10.loc[:,"CVotes10":"CVotesnUS"].columns].astype(int)

# %%
genre_top_10
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Action       102144    114433    150895     94262     34688     12693
# Adventure     94596    105636    138482     86367     31896     11551
# Animation     61960     72566    104837     65707     22825      7551
# Biography     47333     77867    123948     74054     23644      7702
# Comedy        60157     77173    108993     69176     26099      9863
# Crime         52229     87919    129045     74671     25308      8971
# Drama         52375     75928    109339     66456     23528      8497
# Romance       42304     53037     82252     54833     21637      8530
# Sci-Fi       136781    148873    176646    106005     39518     14951
# Thriller      83207    112730    153336     90446     32003     11534
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# Action         5386      3064      2115      5524      349581         67916
# ...

# %% [markdown]
# # Subtask 3.2: Genre Counts!
#  Now let's plot the bar graph ' genres vs cnt '

# %%
sns.barplot( x ="cnt" , y = genre_top_10.index  , data = genre_top_10)
plt.show()

# %% [markdown]
# #  Subtask 3.3: Gender and Genre

# %%
# Task is that we are going to plot the Heat Map, That will compere the Male & Female Voting

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
ax=sns.heatmap(genre_top_10[["CVotesU18M","CVotes1829M","CVotes3044M","CVotes45AM"]],annot=True,cmap="coolwarm")
plt.subplot(1,2,2)

ax=sns.heatmap(genre_top_10[["CVotesU18F","CVotes1829F","CVotes3044F","CVotes45AF"]],annot=True,cmap="coolwarm")
plt.show()

# %%
genre_top_10
# VotesM VotesM	VotesF	VotesU18	VotesU18M	VotesU18F	Votes1829	Votes1829M	Votes1829F	Votes3044	Votes3044M
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Action       102144    114433    150895     94262     34688     12693
# Adventure     94596    105636    138482     86367     31896     11551
# Animation     61960     72566    104837     65707     22825      7551
# Biography     47333     77867    123948     74054     23644      7702
# Comedy        60157     77173    108993     69176     26099      9863
# Crime         52229     87919    129045     74671     25308      8971
# Drama         52375     75928    109339     66456     23528      8497
# Romance       42304     53037     82252     54833     21637      8530
# Sci-Fi       136781    148873    176646    106005     39518     14951
# Thriller      83207    112730    153336     90446     32003     11534
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# Action         5386      3064      2115      5524      349581         67916
# ...

# %%
# Now let's plot it again with Voters only

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
ax=sns.heatmap(genre_top_10[["VotesU18M","Votes1829M","Votes3044M","Votes45AM"]],annot=True,cmap="coolwarm")
plt.subplot(1,2,2)

ax=sns.heatmap(genre_top_10[["VotesU18F","Votes1829F","Votes3044F","Votes45AF"]],annot=True,cmap="coolwarm")
plt.show()

# %%
df
# Out:
#                                               Title  title_year   budget  \
# 97       Star Wars: Episode VII - The Force Awakens        2015  24500.0
# 11                                     The Avengers        2012  22000.0
# 47                                         Deadpool        2016   5800.0
# 32                  The Hunger Games: Catching Fire        2013  13000.0
# 12                                      Toy Story 3        2010  20000.0
# 8                             The Dark Knight Rises        2012  25000.0
# 45                                   The Lego Movie        2014   6000.0
# 1                                          Zootopia        2016  15000.0
# 41                                    Despicable Me        2010   6900.0
# 18                                       Inside Out        2015  17500.0
# 34                                          Gravity        2013  10000.0
# 19                          Guardians of the Galaxy        2014  17000.0
# ...

# %% [markdown]
# #  Task 3.4

# %%
df[['IFUS']] = df[["Country"]]


# Creating New Data Frame by Name df_by_genre

# df_by_genre = df.loc[:,"CVotes10":"VotesnUS"]
# df_by_genre[["genre_1","genre_2","genre_3"]] = df[["genre_1","genre_2","genre_3"]]

# %%
df.loc[df['IFUS'] == "USA"]

# %% [markdown]
# # Subtask 3.5: Top 1000 Voters Vs Genres
#
# 1) Sort the dataframe genre_top10 based on the value of CVotes1000 in a descending order.
#
# 2) Make a seaborn barplot for genre vs CVotes1000.
#
# 3)Write your inferences. You can also try to relate it with the heatmaps you did in the previous subtasks.

# %%
# Counting Number of CVotes1000 

df['CVotes1000'].count()
# Out:
# 100

# %%
genre_top_10.sort_values(by = 'CVotes1000' ,ascending=False)
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Sci-Fi       136781    148873    176646    106005     39518     14951
# Action       102144    114433    150895     94262     34688     12693
# Thriller      83207    112730    153336     90446     32003     11534
# Adventure     94596    105636    138482     86367     31896     11551
# Crime         52229     87919    129045     74671     25308      8971
# Comedy        60157     77173    108993     69176     26099      9863
# Biography     47333     77867    123948     74054     23644      7702
# Drama         52375     75928    109339     66456     23528      8497
# Animation     61960     72566    104837     65707     22825      7551
# Romance       42304     53037     82252     54833     21637      8530
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# Sci-Fi         6583      3876      2715      6731      422437         83618
# ...

# %%
genre_top_10
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Action       102144    114433    150895     94262     34688     12693
# Adventure     94596    105636    138482     86367     31896     11551
# Animation     61960     72566    104837     65707     22825      7551
# Biography     47333     77867    123948     74054     23644      7702
# Comedy        60157     77173    108993     69176     26099      9863
# Crime         52229     87919    129045     74671     25308      8971
# Drama         52375     75928    109339     66456     23528      8497
# Romance       42304     53037     82252     54833     21637      8530
# Sci-Fi       136781    148873    176646    106005     39518     14951
# Thriller      83207    112730    153336     90446     32003     11534
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# Action         5386      3064      2115      5524      349581         67916
# ...

# %%
sns.barplot(x = 'CVotes1000' , y = genre_top_10.index , data = genre_top_10)
plt.show()

# %%
# Interface = Here I can Notice that Sci-Fi movies have LArgge Number of votes
